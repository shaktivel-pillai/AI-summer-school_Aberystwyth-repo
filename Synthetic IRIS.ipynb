# %%
import matplotlib.pyplot as plt
from scipy.io import readsav
import numpy as np
import pandas as pd

# %%
f = readsav(r"C:\Users\shp40\Downloads\iris_l2_20131005_081757_3844009602_SJI_1400_t000_synth.dat")
print(f.keys())
# Out:
# dict_keys(['im', 'imbp', 'maskbp', 'xc', 'yc', 'tc', 'xsig', 'ysig', 'tsig', 'amp', 'bptot', 'nbp', 'speed', 'maxb', 'duration', 'area'])

# %%
x=f['xc']

# %%
print(len(x))
# Out:
# 9981

# %%
print(len(f['xc']))
# Out:
# 9981

# %%
print(f['xc'])
# Out:
# [ 75 299 302 ... 129 167 303]

# %%
plt.imshow((f['im'])[10], origin='lower')

# %%
print(len(f['im']))
# Out:
# 120
